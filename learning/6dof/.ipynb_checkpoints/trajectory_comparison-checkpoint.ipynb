# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
import casadi as cs
import matplotlib.pyplot as plt
import matplotlib
from toppysail.utils import util_functions as ut
from casadi_kinodynamics.utils import symbolic_robot
from toppysail.casadi_dev import nlps
from toppysail.casadi_dev import opt_problem_formulations

# %%
with open('../../../data_lab_04.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
font = {'family' : 'normal',
        'size'   : 14}

matplotlib.rc('font', **font)

# %%
len_opt = []
len_pred = []
for iteration in b:
    qi = iteration['qi']
    qf = iteration['qf']
    q = iteration['q']
    dq = iteration['dq']
    q_msr = iteration['q_msr']

    N = 14
    sym_robot = symbolic_robot.symbolic_robot(robot_name='IRB1100_4_058',
                                              tool_mass=0.,
                                              tool_frame=[0., 0., 0.25, 0., 0., 0.],
                                              tool_cog=[0.0, 0., 0.],
                                              tool_inertia=[0., 0., 0., 0., 0., 0.],
                                              load_casadi_fnc=True)

    # generate a problem
    problem = opt_problem_formulations.problem_136b_X_q_qd_dt_U_qdd(sym_robot)

    nlp_params = nlps.Parameters(N=N, cost_coeff_jerk=1e-7)

    # generate nlp from the problem and solve it
    sol = nlps.generate_and_solve_nlp(problem, qi=qi.tolist(), qf=qf.tolist(),  p=nlp_params)

    # interpolate the optimal solution
    sol_intrp = problem.interpolate_solution(sol, dt_resample=0.004)
    
    len_opt.append( len(sol_intrp["q"]) )
    len_pred.append( len(q) )
# Out:
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      182
# Total number of inequality constraints...............:      252
#         inequality constraints with only lower bounds:       84
#    inequality constraints with lower and upper bounds:       84
#         inequality constraints with only upper bounds:       84
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 3.1399987e-001 2.10e+000 6.67e-002  -7.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 3.1133072e-001 1.90e+000 2.37e+002  -7.0 2.33e+002    -  2.72e-001 9.35e-002h  3
#    2 1.7912200e-001 1.84e+000 2.36e+002  -7.0 5.85e+001    -  1.92e-001 4.60e-002H  1
#    3 1.9166830e-001 1.83e+000 3.11e+002  -7.0 8.10e+002    -  3.80e-004 6.02e-003h  5
#    4 2.8172451e-001 1.75e+000 2.59e+002  -7.0 4.40e+002    -  1.46e-007 4.16e-002h  3
#    5 2.9800936e-001 1.72e+000 2.55e+002  -7.0 2.30e+002    -  3.42e-001 1.49e-002h  5
#    6 3.0523858e-001 1.71e+000 2.52e+002  -7.0 1.97e+002    -  1.03e-001 8.17e-003h  6
#    7 3.0869635e-001 1.70e+000 2.51e+002  -7.0 1.82e+002    -  5.29e-001 4.29e-003h  7
#    8 3.1029935e-001 1.70e+000 2.51e+002  -7.0 1.43e+002    -  1.20e-001 2.68e-003h  8
#    9 3.1112175e-001 1.70e+000 2.50e+002  -7.0 1.32e+002    -  4.30e-001 1.44e-003h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 3.9244291e-001 1.46e+000 1.99e+002  -7.0 1.13e+002    -  1.33e-001 1.33e-001h  3
#   11 4.3615680e-001 1.28e+000 1.73e+002  -7.0 3.45e+001    -  6.97e-001 1.25e-001h  4
#   12 4.7033700e-001 1.12e+000 1.52e+002  -7.0 4.15e+001    -  4.67e-001 1.25e-001h  4
#   13 7.7723759e-001 6.45e-001 1.69e+002  -7.0 4.83e+001    -  5.82e-001 1.00e+000w  1
#   14 4.9653737e-001 1.10e+000 1.49e+002  -7.0 3.27e+002  -4.0 2.80e-001 2.74e-001w  1
#   15 5.1321294e-001 1.15e-001 2.62e+001  -7.0 2.59e+001    -  7.28e-001 1.00e+000w  1
#   16 4.9671898e-001 4.54e-004 8.12e-001  -7.0 1.55e+001    -  7.88e-001 1.00e+000h  1
#   17 4.8661033e-001 1.00e-003 5.36e-002  -7.0 1.52e+001    -  8.33e-001 1.00e+000h  1
#   18 4.7824242e-001 3.54e-003 2.09e-002  -7.0 1.34e+001    -  6.00e-001 1.00e+000h  1
#   19 4.7349860e-001 1.14e-003 1.19e-002  -7.0 6.03e+000    -  6.20e-001 1.00e+000h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 4.7099556e-001 1.10e-003 2.68e-003  -7.0 5.31e+000    -  9.32e-001 1.00e+000h  1
#   21 4.7024202e-001 6.97e-004 9.88e-004  -7.0 4.38e+000    -  9.74e-001 8.05e-001h  1
#   22 4.6998026e-001 2.57e-004 6.37e-004  -7.0 2.61e+000    -  1.00e+000 8.79e-001h  1
#   23 4.6992386e-001 2.07e-005 9.42e-005  -7.0 8.89e-001    -  1.00e+000 1.00e+000h  1
#   24 4.6992150e-001 8.87e-008 6.38e-007  -7.0 8.26e-002    -  1.00e+000 1.00e+000h  1
#   25 4.6992149e-001 7.26e-012 1.73e-010  -7.0 1.09e-003    -  1.00e+000 1.00e+000h  1
#   26 4.6992090e-001 8.52e-010 4.81e-009  -9.0 4.39e-003    -  1.00e+000 1.00e+000h  1
#
# Number of Iterations....: 26
#
#                                    (scaled)                 (unscaled)
# Objective...............:  4.6992089646992785e-001   4.6992089646992785e-001
# Dual infeasibility......:  4.8070279052288918e-009   4.8070279052288918e-009
# Constraint violation....:  8.5213436307185475e-010   8.5213436307185475e-010
# Complementarity.........:  1.0300190164279478e-009   1.0300190164279478e-009
# Overall NLP error.......:  4.8070279052288918e-009   4.8070279052288918e-009
#
#
# Number of objective function evaluations             = 102
# Number of objective gradient evaluations             = 27
# Number of equality constraint evaluations            = 102
# Number of inequality constraint evaluations          = 102
# Number of equality constraint Jacobian evaluations   = 27
# Number of inequality constraint Jacobian evaluations = 27
# Number of Lagrangian Hessian evaluations             = 26
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.048
# Total CPU secs in NLP function evaluations           =      0.068
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)        0 (       0)       102
#        nlp_g  |  16.00ms (156.86us)  16.11ms (157.97us)       102
#   nlp_grad_f  |        0 (       0)        0 (       0)        28
#   nlp_hess_l  |  31.00ms (  1.19ms)  30.24ms (  1.16ms)        26
#    nlp_jac_g  |  21.00ms (750.00us)  21.31ms (761.14us)        28
#        total  | 116.00ms (116.00ms) 116.11ms (116.11ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.076
# Total CPU secs in NLP function evaluations           =      0.083
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)        0 (       0)       104
#        nlp_g  |   3.00ms ( 28.85us)   2.99ms ( 28.71us)       104
#   nlp_grad_f  |   1.00ms ( 29.41us) 991.00us ( 29.15us)        34
#   nlp_hess_l  |  44.00ms (  1.26ms)  43.19ms (  1.23ms)        35
#    nlp_jac_g  |  33.00ms (767.44us)  33.17ms (771.42us)        43
#        total  | 159.00ms (159.00ms) 159.17ms (159.17ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      182
# Total number of inequality constraints...............:      252
#         inequality constraints with only lower bounds:       84
#    inequality constraints with lower and upper bounds:       84
#         inequality constraints with only upper bounds:       84
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 3.1399987e-001 1.57e+000 6.67e-002  -7.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 3.0557595e-001 1.40e+000 2.74e+002  -7.0 2.11e+002    -  2.93e-001 1.03e-001h  3
#    2 1.7216847e-001 1.34e+000 2.44e+002  -7.0 5.74e+001    -  2.15e-001 6.08e-002H  1
#    3 2.2780283e-001 1.30e+000 8.55e+002  -7.0 7.19e+002    -  3.09e-004 2.78e-002h  3
#    4 2.8528563e-001 1.26e+000 7.88e+002  -7.0 4.11e+002    -  1.47e-006 3.65e-002h  3
#    5 3.0409983e-001 1.23e+000 7.71e+002  -7.0 3.09e+002    -  2.96e-001 1.82e-002h  4
#    6 3.0499974e-001 1.23e+000 7.70e+002  -7.0 2.81e+002    -  8.57e-002 1.09e-003h  8
#    7 3.0543170e-001 1.23e+000 7.70e+002  -7.0 2.79e+002    -  4.94e-001 5.46e-004h  9
#    8 3.9311349e-001 1.04e+000 5.08e+002  -7.0 2.70e+002    -  9.16e-002 1.50e-001H  1
#    9r3.9311349e-001 1.04e+000 9.99e+002   0.0 0.00e+000    -  0.00e+000 2.89e-007R  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r4.0803426e-001 2.55e+000 9.99e+002   0.0 2.83e+005    -  2.01e-004 3.64e-004f  1
#   11r3.2616369e-001 2.54e+000 9.98e+002   0.0 7.50e+002   0.0 1.27e-003 1.11e-003f  1
#   12r3.1891115e-001 2.53e+000 9.96e+002   0.0 1.64e+002  -0.5 5.03e-002 2.48e-003f  1
#   13r3.1686153e-001 2.52e+000 9.93e+002   0.0 9.30e+001  -1.0 5.53e-002 2.71e-003f  1
#   14r3.2049748e-001 2.49e+000 9.61e+002   0.0 2.04e+002  -1.4 6.24e-002 3.19e-002f  1
#   15r3.8202434e-001 2.37e+000 8.98e+002   0.0 1.23e+002  -1.0 1.63e-002 6.63e-002f  1
#   16r3.8783211e-001 2.35e+000 8.89e+002   0.0 1.48e+001   0.3 9.36e-002 9.62e-003f  1
#   17r4.1685262e-001 2.33e+000 8.82e+002   0.0 4.85e+001  -0.2 3.90e-002 9.43e-003f  1
#   18r4.8145350e-001 2.25e+000 8.47e+002   0.0 1.25e+001   0.3 2.91e-002 3.96e-002f  1
#   19r5.2002733e-001 2.23e+000 8.42e+002   0.0 1.16e+002  -0.2 2.19e-002 5.72e-003f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   
# Objective...............:  4.1566648042480331e-001   4.1566648042480331e-001
# Dual infeasibility......:  5.7301956083587082e-011   5.7301956083587082e-011
# Constraint violation....:  1.2434497875801753e-013   1.2434497875801753e-013
# Complementarity.........:  9.1022335564104816e-010   9.1022335564104816e-010
# Overall NLP error.......:  9.1022335564104816e-010   9.1022335564104816e-010
#
#
# Number of objective function evaluations             = 88
# Number of objective gradient evaluations             = 27
# Number of equality constraint evaluations            = 88
# Number of inequality constraint evaluations          = 88
# Number of equality constraint Jacobian evaluations   = 45
# Number of inequality constraint Jacobian evaluations = 45
# Number of Lagrangian Hessian evaluations             = 43
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.121
# Total CPU secs in NLP function evaluations           =      0.101
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)        0 (       0)        88
#        nlp_g  |   8.00ms ( 90.91us)   7.95ms ( 90.32us)        88
#   nlp_grad_f  |        0 (       0)        0 (       0)        28
#   nlp_hess_l  |  59.00ms (  1.40ms)  58.56ms (  1.39ms)        42
#    nlp_jac_g  |  32.00ms (695.65us)  31.97ms (694.98us)        46
#        total  | 222.00ms (222.00ms) 221.42ms (221.42ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      182
# Total number of inequality constraints...............:      252
#         inequality constraints with only lower bounds:       84
#    inequality constraints with lower and upper bounds:       84
#         inequality constraints with only upper bounds:       84
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 3.1399987e-001 1.94e+000 6.67e-002  -7.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 3.0809160e-001 1.79e+000 2.32e+002  -7.0 2.75e+002    -  2.41e-001 7.92e-002h  3
#    2 1.7621940e-001 1.75e+000 2.22e+002  -7.0 6.50e+001    -  1.42e-001 3.09e-002H  1
#    3 2.2455198e-001 1.71e+000 7.47e+002  -7.0 9.17e+002    -  3.49e-004 2.12e-002h  3
#    4 2.7738260e-001 1.66e+000 6.93e+002  -7.0 5.06e+002    -  7.00e-007 2.87e-002h  3
#    5 3.1277798e-001 1.61e+000 6.61e+002  -7.0 3.66e+002    -  2.64e-001 2.98e-002h  3
#    6 3.1349333e-001 1.61e+000 6.60e+002  -7.0 2.91e+002    -  9.37e-002 8.78e-004h  8
#    7 3.1383686e-001 1.61e+000 6.60e+002  -7.0 2.89e+002    -  5.03e-001 4.39e-004h  9
#    8 3.1396894e-001 1.61e+000 6.60e+002  -7.0 2.75e+002    -  9.65e-002 2.30e-004h 10
#    9 3.1398528e-001 1.61e+000 6.60e+002  -7.0 2.71e+002    -  3.74e-001 2.91e-005h 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   
  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40 4.5602365e-001 5.78e-009 5.23e-008  -7.0 2.32e-002    -  1.00e+000 1.00e+000h  1
#   41 4.5602286e-001 5.14e-010 2.61e-009  -9.0 4.77e-003    -  1.00e+000 1.00e+000h  1
#
# Number of Iterations....: 41
#
#                                    (scaled)                 (unscaled)
# Objective...............:  4.5602285523979880e-001   4.5602285523979880e-001
# Dual infeasibility......:  2.6073066057054418e-009   2.6073066057054418e-009
# Constraint violation....:  5.1360471431394217e-010   5.1360471431394217e-010
# Complementarity.........:  1.0657602297496741e-009   1.0657602297496741e-009
# Overall NLP error.......:  2.6073066057054418e-009   2.6073066057054418e-009
#
#
# Number of objective function evaluations             = 198
# Number of objective gradient evaluations             = 42
# Number of equality constraint evaluations            = 198
# Number of inequality constraint evaluations          = 198
# Number of equality constraint Jacobian evaluations   = 42
# Number of inequality constraint Jacobian evaluations = 42
# Number of Lagrangian Hessian evaluations             = 41
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.109
# Total CPU secs in NLP function evaluations           =      0.096
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)        0 (       0)       198
#        nlp_g  |  14.00ms ( 70.71us)  13.98ms ( 70.62us)       198
#   nlp_grad_f  |   1.00ms ( 23.26us) 991.00us ( 23.05us)        43
#   nlp_hess_l  |  49.00ms (  1.20ms)  47.75ms (  1.16ms)        41
#    nlp_jac_g  |  29.00ms (674.42us)  28.95ms (673.35us)        43
#        total  | 205.00ms (205.00ms) 205.46ms (205.46ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      182
# Total number of inequality constraints...............:      252
#         inequality constraints with only lower bounds:       84
#    inequality constraints with lower and upper bounds:       84
#         inequality constraints with only upper bounds:       84
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 3.1399987e-001 1.48e+000 6.67e-002  -7.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 3.0426108e-001 1.29e+000 2.41e+002  -7.0 1.73e+002    -  3.35e-001 1.26e-001h  3
#    2 1.6892504e-001 1.19e+000 2.45e+002  -7.0 4.48e+001    -  2.94e-001 1.00e-001H  1
#    3 2.2997706e-001 1.16e+000 6.16e+002  -7.0 6.64e+002    -  3.91e-004 3.06e-002h  3
#    4 2.9338567e-001 1.11e+000 5.66e+002  -7.0 3.70e+002    -  2.35e-001 4.11e-002h  3
#    5 3.0299693e-001 1.10e+000 5.59e+002  -7.0 2.69e+002    -  5.13e-002 1.06e-002h  5
#    6 3.0405495e-001 1.09e+000 5.59e+002  -7.0 2.53e+002    -  4.63e-001 1.32e-003h  8
#    7 3.0423867e-001 1.09e+000 5.58e+002  -7.0 2.43e+002    -  7.71e-002 3.41e-004h 10
#    8 3.0424977e-001 1.09e+000 5.58e+002  -7.0 2.41e+002    -  3.58e-001 2.15e-005h 14
#    9 3.4808754e-001 9.89e-001 4.50e+002  -7.0 2.26e+002    -  8.23e-002 9.40e-002h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  80.00us (833.33ns)        96
#        nlp_g  |   2.00ms ( 20.83us)   2.20ms ( 22.87us)        96
#   nlp_grad_f  |        0 (       0)        0 (       0)        29
#   nlp_hess_l  |  29.00ms (  1.07ms)  29.33ms (  1.09ms)        27
#    nlp_jac_g  |   5.00ms (172.41us)   4.99ms (171.97us)        29
#        total  | 112.00ms (112.00ms) 111.76ms (111.76ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      182
# Total number of inequality constraints...............:      252
#         inequality constraints with only lower bounds:       84
#    inequality constraints with lower and upper bounds:       84
#         inequality constraints with only upper bounds:       84
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 3.1399987e-001 9.91e-001 6.67e-002  -7.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 2.9162596e-001 7.67e-001 2.56e+002  -7.0 9.98e+001    -  4.77e-001 2.28e-001h  3
#    2 1.4007606e-001 1.45e+000 7.63e+002  -7.0 3.63e+001    -  5.68e-001 1.00e+000H  1
#    3 1.8449798e-001 1.43e+000 8.80e+002  -7.0 1.05e+003    -  2.04e-002 5.51e-002h  2
#    4 2.6096462e-001 1.37e+000 8.55e+002  -7.0 5.26e+002    -  1.81e-001 5.50e-002h  2
#    5 2.8125800e-001 1.34e+000 8.38e+002  -7.0 3.41e+002    -  3.11e-001 2.12e-002h  3
#    6 2.8853932e-001 1.33e+000 8.31e+002  -7.0 3.09e+002    -  4.84e-001 8.78e-003h  4
#    7 2.9158449e-001 1.33e+000 8.27e+002  -7.0 3.08e+002    -  3.19e-001 3.85e-003h  5
#    8 3.3864282e-001 1.26e+000 7.83e+002  -7.0 3.03e+002    -  4.47e-001 5.88e-002h  1
#    9 3.4498083e-001 1.05e+000 6.64e+002  -7.0 9.34e+001    -  4.24e-001 1.67e-001H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 5.0757638e-001 4.60e-001 1.50e+002  -7.0 3.71e+001    -  7.15e-001 1.00e+000h  1
#   11 4.4535168e-001 1.19e-002 1.25e+001  -7.0 2.24e+000  -2.0 3.38e-001 1.00e+000h  1
#   12 4.1621587e-001 1.50e-002 1.98e+001  -7.0 3.88e+001    -  8.54e-001 1.00e+000h  1
#   13 3.6572854e-001 7.10e-002 1.09e+000  -7.0 2.40e+001    -  6.46e-001 1.00e+000h  1
#   14 3.5644860e-001 1.09e-002 9.74e-002  -7.0 1.87e+001    -  8.71e-001 1.00e+000h  1
#   15 3.5086276e-001 1.00e-002 3.28e-002  -7.0 1.01e+001    -  8.63e-001 1.00e+000h  1
#   16 3.5087310e-001 1.59e-003 5.77e-003  -7.0 4.74e+000    -  9.74e-001 1.00e+000h  1
#   17 3.5096392e-001 7.52e-005 2.46e-004  -7.0 1.12e+000    -  1.00e+000 1.00e+000h  1
#   18 3.5096871e-001 1.26e-007 3.55e-007  -7.0 5.08e-002    -  1.00e+000 1.00e+000h  1
#   19 3.5096872e-001 1.65e-010 7.51e-010  -9.0 1.20e-003    -  1.00e+000 1.00e+000h  1
#
# Number of Iterations....: 19
#
#                                    (scaled)                 (unscaled)
# Objective...............:  3.5096871808179264e-001   3.5096871808179264e-001
# Dual infeasibility......:  7.5050581946497184e-010   7.5050581946497184e-010
# Constraint violation....:  1.6471224384417837e-010   1.6471224384417837e-010
# Complementarity.........:  9.1535299376186991e-010   9.1535299376186991e-010
# Overall NLP error.......:  9.1535299376186991e-010   9.1535299376186991e-010
#
#
# Number of objective function evaluations             = 38
# Number of objective gradient evaluations             = 20
# Number of equality constraint evaluations            = 38
# Number of inequality constraint evaluations          = 38
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 20
# Number of Lagrangian Hessian evaluations             = 19
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.041
# Total CPU secs in NLP function evaluations           =      0.045
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 26.32us)   1.01ms ( 26.50us)        38
#        nlp_g  |   2.00ms ( 52.63us)   2.00ms ( 52.66us)        38
#   nlp_grad_f  |        0 (       0)        0 (       0)        21
#   nlp_hess_l  |  26.00ms (  1.37ms)  25.94ms (  1.37ms)        19
#    nlp_jac_g  |  16.00ms (761.90us)  15.98ms (760.86us)        21
#        total  |  87.00ms ( 87.00ms)  86.77ms ( 86.77ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      182
# Total number of inequality constraints...............:      252
#         inequality constraints with only lower bounds:       84
#    inequality constraints with lower and upper bounds:       84
#         inequality constraints with only upper bounds:       84
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 3.1399987e-001 1.29e+000 6.67e-002  -7.0 0.00e+000    -  0.00e+000 0.00e+000   0
#    1 3.0520385e-001 1.07e+000 3.38e+002  -7.0 1.33e+002    -  4.09e-001 1.73e-001h  3
#    2 1.5320088e-001 8.22e-001 3.28e+002  -7.0 4.40e+001    -  4.39e-001 2.80e-001H  1
#    3 2.2420354e-001 7.91e-001 7.17e+002  -7.0 6.22e+002    -  2.45e-004 3.79e-002h  3
#    4 2.6963899e-001 7.72e-001 6.95e+002  -7.0 3.65e+002    -  5.52e-006 2.41e-002h  4
#    5 2.8888397e-001 7.63e-001 6.86e+002  -7.0 3.22e+002    -  9.31e-002 1.19e-002h  5
#    6 2.9750100e-001 7.58e-001 6.82e+002  -7.0 3.07e+002    -  5.70e-002 5.87e-003h  6
#    7 3.0154116e-001 7.56e-001 6.80e+002  -7.0 3.00e+002    -  1.64e-001 2.91e-003h  7
#    8 5.2639736e-001 6.64e-001 4.24e+002  -7.0 2.98e+002    -  7.07e-002 1.84e-001h  1
#    9r5.2639736e-001 6.64e-001 9.99e+002  -0.1 0.00e+000    -  0.00e+000 3.30e-008R  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r5.2509190e-001 6.13e-001 1.00e+003  -0.1 1.54e+006    -  3.69e-005 3.44e-007f  9
#   11r5.3267249e-001 6.05e-001 9.99e+002  -0.1 1.40e+003    -  5.28e-003 5.58e-004f  1
#   12 5.3335657e-001 6.02e-001 1.75e+001  -7.0 1.19e+002    -  6.18e-001 4.30e-003h  1
#   13 5.1669932e-001 2.92e-001 9.33e+001  -7.0 5.13e+001    -  3.38e-001 5.00e-001h  2
#   14 5.5899054e-001 8.75e-002 3.02e+001  -7.0 1.53e+001    -  7.22e-001 1.00e+000h  1
#   15 5.3782153e-001 3.94e-003 1.70e+000  -7.0 4.32e+000    -  9.07e-001 1.00e+000h  1
#   16 4.6792542e-001 4.96e-002 8.51e-001  -7.0 4.08e+001    -  5.94e-002 1.00e+000h  1
#   17 4.4051054e-001 1.75e-002 2.98e-002  -7.0 9.84e+000    -  9.16e-001 1.00e+000h  1
#   18 3.9440384e-001 8.45e-002 1.17e-001  -7.0 2.31e+001    -  8.30e-001 1.00e+000h  1
#   19 3.8906147e-001 1.88e-002 4.92e-002  -7.0 1.42e+001    -  9.01e-001 1.00e+000h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 3.8870340e-001 3.47e-003 1.15e-002  -7.0 7.68e+000    -  9.58e-001 1.00e+000h  1
#   21 3.8872842e-001 5.05e-004 1.43e-003  -7.0 3.53e+000    -  9.79e-001 1.00e+000h  1
#   22 3.8872864e-001 4.99e-005 2.14e-004  -7.0 1.53e+000    -  1.00e+000 1.00e+000h  1
#   23 3.8872860e-001 3.19e-006 1.08e-005  -7.0 4.85e-001    -  1.00e+000 1.00e+000h  1
#   24 3.8872866e-001 4.65e-008 1.81e-007  -7.0 6.30e-002    -  1.00e+000 1.00e+000h  1
#   25 3.8872867e-001 1.51e-011 6.15e-011  -7.0 1.15e-003    -  1.00e+000 1.00e+000h  1
#   26 3.8872866e-001 1.07e-009 3.55e-009  -9.0 4.56e-003    -  1.00e+000 1.00e+000h  1
#
# Number of Iterations....: 26
#
#                                    (scaled)                 (unscaled)
# Objective...............:  3.8872866476439627e-001   3.8872866476439627e-001
# Dual infeasibility......:  3.5467142065954586e-009   3.5467142065954586e-009
# Constraint violation....:  1.0738832045831259e-009   1.0738832045831259e-009
# Complementarity.........:  1.0414538920085409e-009   1.0414538920085409e-009
# Overall NLP error.......:  3.5467142065954586e-009   3.5467142065954586e-009
#
#
# Number of objective function evaluations             = 68
# Number of objective gradient evaluations             = 26
# Number of equality constraint evaluations            = 68
# Number of inequality constraint evaluations          = 68
# Number of equality constraint Jacobian evaluations   = 28
# Number of inequality constraint Jacobian evaluations = 28
# Number of Lagrangian Hessian evaluations             = 26
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.065
# Total CPU secs in NLP function evaluations           =      0.038
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 14.71us)   1.01ms ( 14.79us)        68
#        nlp_g  |   4.00ms ( 58.82us)   4.00ms ( 58.81us)        68
#   nlp_grad_f  |        0 (       0)        0 (       0)        27
#   nlp_hess_l  |  20.00ms (800.00us)  19.92ms (796.88us)        25
#    nlp_jac_g  |  14.00ms (482.76us)  14.71ms (507.28us)        29
#        total  | 103.00ms (103.00ms) 103.06ms (103.06ms)         1
# Problem model generated.
# Warning: Default initialization.
# NLP with 285 variables and 434 constraints generated.
# Solver instantiated.
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      820
# Number of nonzeros in inequality constraint Jacobian.:     2892
# Number of nonzeros in Lagrangian Hessian.............:     1816
#
# Total number of variables............................:      249
#                      variables with only lower bounds:       15
#                 variables with lower and upper bounds:      156
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:
#   25 4.1457603e-001 3.72e-009 8.40e-008  -7.0 2.39e-002    -  1.00e+000 1.00e+000h  1
#   26 4.1457573e-001 1.32e-008 6.18e-008  -9.0 3.06e-002    -  1.00e+000 1.00e+000h  1
#   27 4.1457573e-001 2.25e-011 4.89e-010  -9.0 1.84e-003    -  1.00e+000 1.00e+000h  1
#
# Number of Iterations....: 27
#
#                                    (scaled)                 (unscaled)
# Objective...............:  4.1457572752229116e-001   4.1457572752229116e-001
# Dual infeasibility......:  4.8909922061525708e-010   4.8909922061525708e-010
# Constraint violation....:  2.2479351713400320e-011   2.2479351713400320e-011
# Complementarity.........:  9.4881122312758935e-010   9.4881122312758935e-010
# Overall NLP error.......:  9.4881122312758935e-010   9.4881122312758935e-010
#
#
# Number of objective function evaluations             = 85
# Number of objective gradient evaluations             = 28
# Number of equality constraint evaluations            = 85
# Number of inequality constraint evaluations          = 85
# Number of equality constraint Jacobian evaluations   = 28
# Number of inequality constraint Jacobian evaluations = 28
# Number of Lagrangian Hessian evaluations             = 27
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.061
# Total CPU secs in NLP function evaluations           =      0.065
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)        0 (       0)        85
#        nlp_g  |   7.00ms ( 82.35us)   7.05ms ( 82.94us)        85
#   nlp_grad_f  |   1.00ms ( 34.48us) 993.00us ( 34.24us)        29
#   nlp_hess_l  |  35.00ms (  1.30ms)  34.88ms (  1.29ms)        27
#    nlp_jac_g  |  23.00ms (793.10us)  22.77ms (785.24us)        29
#        total  | 126.00ms (126.00ms) 125.67ms (125.67ms)         1

# %%
q_m = q_msr[10:20+len(q)] * np.pi/180
dq_m = np.gradient(q_m, axis=0) / 0.004

t_m = np.arange(len(q_m)) * 0.004
t_r = np.arange(len(q)) * 0.004
t_o = np.arange(len(sol_intrp["q"][:,0])) * 0.004
plt.figure(figsize=[8,6.5])
plt.subplot(211)
plt.plot(t_r, q[:,0], '-.r', label='predict ref')
plt.plot(t_o, sol_intrp["q"][:,0], '-.c', label='optimal')
plt.grid()
plt.plot(t_m, q_m[:,0], '-b', label='tracking res')
plt.plot(t_m, np.ones_like(t_m)*sym_robot.q_min[0], '-.y')
plt.plot(t_m, np.ones_like(t_m)*sym_robot.q_max[0], '-.y')
plt.ylabel("q")
plt.legend()
plt.subplot(212)
# dq_ = np.concatenate([np.zeros([6,6]), dq])
plt.plot(t_r, dq[:,0], '-.r')
plt.plot(t_m, dq_m[:,0], '-b')
plt.plot(t_o, sol_intrp["qd"][:,0], '-.c')
plt.grid()
plt.xlabel("Time [ms]")
plt.ylabel("dq")
plt.tight_layout()
plt.savefig("../../plots/ordinary/lab_res_2.jpg", dpi=200)

# %%
opt_t = np.array(len_opt) * 0.004
pred_t = np.array(len_pred) * 0.004
subopt = 100 * np.sum(pred_t - opt_t) / np.sum(opt_t)
subopt
# Out:
# 1.472392638036808

# %%
plt.figure(figsize=[5,4])
plt.plot(opt_t, 'r.', label="optimal")
plt.plot(pred_t, 'b.', label="prediction")
plt.xlabel("Trajectory number")
plt.ylabel("Time [s]")
plt.grid()
plt.tight_layout()
plt.legend()
plt.savefig("../../plots/ordinary/traj_speed.jpg", dpi = 200)
plt.show()
